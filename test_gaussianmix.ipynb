# %%
import numpy as np
# %pylab inline
import PyMC_GPU as pm
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'seed']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import mixgaussian as mg
import theano.tensor as T

# %%
seed=121
    
dim=2
batchsize=4
num_onestep=1000
num_exchange=2

# %%
rng = np.random.RandomState(seed)
f=mg.mixgaussian(dim,size=2,seed=123,rand=False,mu0=3,mu1=-3)

# %%
r=pm.Rep(f,dim,batchsize,num_onestep)
r.gen(num_onestep)
# Out:
# C:\Python27\lib\site-packages\theano\scan_module\scan_perform_ext.py:85: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *
# PyMC_GPU.py:90: UserWarning: Updating an `OrderedUpdates` with a non-ordered dictionary with 2+ elements could make your code non-deterministic
#   u.update({self.xs:xsn[-1],self.Es:Esn[-1]})

# %%
#vbetas=range(1,batchsize+1)
vbetas=[i/batchsize for i in range(1,batchsize+1)]
d=r.sample(vbetas,num_exchange/10,num_exchange)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
x=d[0]
x.shape
# Out:
# (40003, 4, 2)

# %%
x[0:10,0,0]
# Out:
# array([ 0.        ,  0.        ,  0.41253531,  0.40557989,  0.43179324,
#         0.43468937,  0.41673177,  0.43778956,  0.45005918,  0.4644917 ])

# %%
plt.title("x")
for i in xrange(4):
    plt.plot(x[:,i,0])

# %%
for i in xrange(4):
    plt.plot(x[:,i,1])

# %%
E=d[1]
E.shape
for i in xrange(4):
    plt.plot(E[:,i])

# %% [markdown]
# ## low tempareture

# %%
vbetas=[1]*batchsize
dl=r.sample(vbetas,num_exchange/10,num_exchange)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
x=dl[0]
x[0:10,0,0]
# Out:
# array([ 0.        ,  0.        , -2.96735168, -2.98939657, -3.00201344,
#        -3.00280762, -3.00825953, -2.99482369, -3.00997591, -3.02778101])

# %%
plt.title("x")
for i in xrange(4):
    plt.plot(x[:,i,0])
