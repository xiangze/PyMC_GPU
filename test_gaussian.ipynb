# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['seed']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import PyMC_GPU as pm

# %%
import mixgaussian as mg
import theano.tensor as T

# %%
seed=121
    
dim=2
batchsize=4
num_onestep=1000
num_exchange=4

# %%
rng = np.random.RandomState(seed)
f=mg.gaussian(dim,size=2,seed=123,rand=False,mu=2)

# %%
r=pm.Rep(f,dim,batchsize,num_onestep)
r.gen(num_onestep)
# Out:
# C:\Python27\lib\site-packages\theano\scan_module\scan_perform_ext.py:85: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *
# PyMC_GPU.py:90: UserWarning: Updating an `OrderedUpdates` with a non-ordered dictionary with 2+ elements could make your code non-deterministic
#   u.update({self.xs:xsn[-1],self.Es:Esn[-1]})

# %% [markdown]
# ## low tempareture

# %%
vbetas=range(1,batchsize+1)
d=r.sample(vbetas,num_exchange/10,num_exchange)   
x=d[0]
E=d[1]
x.shape
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# (80005, 4, 2)

# %%
for i in xrange(4):
    plt.plot(x[:,i,0])

# %%
E=d[1]
E.shape
for i in xrange(4):
    plt.plot(E[:,i])

# %% [markdown]
# ## all β=1

# %%
vbetas=[1]*batchsize
d1=r.sample(vbetas,num_exchange/10,num_exchange)   
x=d1[0]
x.shape
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# (80005, 4, 2)

# %%
for i in xrange(4):
    plt.plot(x[:,i,0])

# %%
for i in xrange(4):
    plt.plot(x[:1000,i,0])

# %%
for i in xrange(4):
    plt.plot(x[:,i,1])

# %%
E=d1[1]
E.shape
for i in xrange(4):
    plt.plot(E[:,i])

# %%
print 'empirical mean: ', x.mean(axis=0)
print 'empirical_cov(0):\n', np.cov(x[:,0,:].T)
# Out:
# empirical mean:  [[ 0.97973691  2.66969041]
#  [ 0.99543375  2.69150539]
#  [ 1.00182954  2.70207018]
#  [ 0.97476655  2.70666544]]
# empirical_cov:
# [[ 5.41065832 -3.31145707]
#  [-3.31145707  2.97512551]]

# %%
np.savetxt("%d_%d_%d.csv"%(batchsize,num_onestep,num_exchange),d)

# %% [markdown]
# ## High temp

# %%
vbetas=[i/batchsize for i in range(1,batchsize+1)]
dh=r.sample(vbetas,num_exchange/10,num_exchange)   
x=dh[0]
x.shape
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# (80005, 4, 2)

# %%
for i in xrange(4):
    plt.plot(x[:,i,0])
